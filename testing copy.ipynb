# %% [markdown]
# # Testing Notebook
#
# This notebook is formatted so that you can toggle cells by highlighting everything and then cmd + / (comment shortcut).
#
# This way, comments stay as comments and the code toggles on and off.

# %%
import numpy as np
import matplotlib.pyplot as plt
from backups.v1_1.network import Network as Network_v1
from network import Network as Network_v2

data = np.load('mnist.npz')
x_train = data["x_train"] / 255 # NOTE normalizing the data here
y_train = data["y_train"]
x_test = data["x_test"] / 255
y_test = data["y_test"]

# %% [markdown]
# ### Testing Forward Propagation of Network v2

# %%
# # setup net1 and net2 with the same weights and biases
# net1 = Network_v1(hiddenLayerCount=2, hiddenShape=[128, 64], x_train=x_train, y_train=y_train)
# net2 = Network_v2(shape=[784,128,64,10])
# net2.weights = net1.weights.copy()
# net2.biases  = net1.biases.copy()

# # net1 fwd propagate
# z1, a1 = net1.forward_propagate(k=x_test[0] / 255)

# # net2 fwd propagate
# z2, a2 = net2.f_prop(x_input=x_test[0] / 255)

# # results
# print('output activation net1')
# print(a1[-1])
# print('\noutput activation net2')
# print(a2[-1])

# %% [markdown]
# ### Testing Backward Propagation of Network v2

# %%
# # setup net1 and net2 with the same weights and biases
# net1 = Network_v1(hiddenLayerCount=2, hiddenShape=[128, 64], x_train=x_train, y_train=y_train)
# net2 = Network_v2(shape=[784,128,64,10])
# net2.weights = net1.weights.copy()
# net2.biases  = net1.biases.copy()

# # get normalized input
# TEST_IDX = 0
# x_norm = x_test[TEST_IDX] / 255
# y_true = np.zeros((10, 1))
# y_true[y_test[TEST_IDX]] = 1

# # backprop result for net1
# z1, a1   = net1.forward_propagate(k=x_norm)
# dw1, db1 = net1.backward_propagate(x=x_norm, y=y_test[0], a=a1, z=z1)

# # backprop result for net2
# z2, a2   = net2.f_prop(x_input=x_norm)
# dw2, db2 = net2.b_prop(z=z2, a=a2, y_true=y_true)

# print(dw1[-1][0][0:5])
# print(dw2[-1][0][0:5])

# '''
# NOTE BUG in net1, where the derivative of the output layer isn't calculated correectly
# 50% of the time net1 will make a mistake (but net2 is presumably fine)
# '''

# %% [markdown]
# ### Testing Descent Functionality

# %%
def test_accuracy(network, x_test=x_test, y_test=y_test):

    results = np.zeros_like(x_test)

    for i in range(len(x_test)):
        output = network.f_prop(x_test[i], output_only=True)
        
        prediction = np.argmax(output)
        true_val = y_test[i]
    
        if prediction == true_val:
            results[i] = 1

    accuracy = np.mean(results)
    # print(f'network accuracy: {accuracy * 100:.2f}%')
    return np.mean(results)

# %%
ALPHA      = 0.5
MAX_STEPS  = 1000
BATCH_SIZE = 32

net2 = Network_v2(shape=[784,128,64,10])
pre = test_accuracy(net2, x_test=x_test, y_test=y_test)
net2.descend(x_train=x_train,
             y_train=y_train,
             alpha=ALPHA,
             max_steps=MAX_STEPS,
             batch_size=BATCH_SIZE
             )
post = test_accuracy(net2, x_test=x_test, y_test=y_test)


print( '----------------DESCENT SUMMARY----------------')
print(f'alpha = {ALPHA}, max_steps = {MAX_STEPS}, batch_size={BATCH_SIZE}')
print(f'pre-descent:{pre*100:.2f}')
print(f'post-descent:{post*100:.2f}')
# Out:
# ----------------DESCENT SUMMARY----------------
# alpha = 0.5, max_steps = 1000, batch_size=32
# pre-descent:10.69
# post-descent:93.36

# %% [markdown]
# ### Visualizing Improvement Rate

# %%
TOTAL_STEPS = 1000
TEST_EVERY  = 5
net2 = Network_v2(shape=[784,128,64,10])

x = [i for i in range(0,TOTAL_STEPS+1, TEST_EVERY)] 
y = [test_accuracy(net2)]

for i in range(TEST_EVERY, TOTAL_STEPS+1, TEST_EVERY):
    net2.descend(x_train=x_train,y_train=y_train,alpha=0.5,max_steps=TEST_EVERY,batch_size=32)

    y.append(test_accuracy(net2))

plt.scatter(x, y)
plt.show()

# %%
TOTAL_STEPS = 90
TEST_EVERY  = 10
net2 = Network_v2(shape=[784,128,64,10])

x = [i for i in range(0,TOTAL_STEPS+1, TEST_EVERY)]
alpha = [i for i in np.arange(0.1, 1.1, 0.1)]
y_tuple = []

for j in alpha:
    net2 = Network_v2(shape=[784,128,64,10])
    for i in range(TEST_EVERY, TOTAL_STEPS+1, TEST_EVERY):
            net2.descend(x_train=x_train,y_train=y_train,alpha=j,max_steps=TEST_EVERY,batch_size=32)
            y_tuple.append((j, i, test_accuracy(net2)))


x = []
y = []
z = []

for i in range(len(y_tuple)):
      x_i, y_i, z_i = y_tuple[i]
      x.append(x_i)
      y.append(y_i)
      z.append(z_i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 21
#      17 x = []
#      18 y = []
#      19 z = []
#      20 for i in range(len(y_tuple)):
# ---> 21       x_i, y_i, z_i = y_tuple
#      22       x.append(x_i)
#      23       y.append(y_i)
#      24       z.append(z_i)
#
# ValueError: too many values to unpack (expected 3)

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(x, alpha, y, 'green')
ax.set_title('3D Line Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 8
#       4
#       5 fig = plt.figure()
#       6 ax = plt.axes(projection='3d')
#       7
# ----> 8 ax.plot3D(x, alpha, y, 'green')
#       9 ax.set_title('3D Line Plot')
#      10 plt.show()
#
# File c:\Users\marti\Desktop\PP Project\.venv\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1984, in Axes3D.plot(self, xs, ys, zdir, axlim_clip, *args, **kwargs)
#    1981 else:
#    1982     zs = kwargs.pop('zs', 0)
# -> 1984 xs, ys, zs = cbook._broadcast_with_masks(xs, ys, zs)
#    1986 lines = super().plot(xs, ys, *args, **kwargs)
#    1987 for line in lines:
#
# File c:\Users\marti\Desktop\PP Project\.venv\Lib\site-packages\matplotlib\cbook.py:1083, in _broadcast_with_masks(compress, *args)
#    1081 masks = [k.mask for k in args if isinstance(k, np.ma.MaskedArray)]
#    1082 # broadcast to match the shape
# -> 1083 bcast = np.broadcast_arrays(*args, *masks)
#    1084 inputs = bcast[:len(args)]
#    1085 masks = bcast[len(args):]
#
# File c:\Users\marti\Desktop\PP Project\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:577, in broadcast_arrays(subok, *args)
#     570 # nditer is not used here to avoid the limit of 64 arrays.
#     571 # Otherwise, something like the following one-liner would suffice:
#     572 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     573 #                  order='C').itviews
#     575 args = [np.array(_m, copy=None, subok=subok) for _m in args]
# --> 577 shape = _broadcast_shape(*args)
#     579 result = [array if array.shape == shape
#     580           else _broadcast_to(array, shape, subok=subok, readonly=False)
#     581                           for array in args]
#     582 return tuple(result)
#
# File c:\Users\marti\Desktop\PP Project\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:452, in _broadcast_shape(*args)
#     447 """Returns the shape of the arrays that would result from broadcasting the
#     448 supplied arrays against each other.
#     449 """
#     450 # use the old-iterator because np.nditer does not handle size 0 arrays
#     451 # consistently
# --> 452 b = np.broadcast(*args[:64])
#     453 # unfortunately, it cannot handle 64 or more arguments directly
#     454 for pos in range(64, len(args), 63):
#     455     # ironically, np.broadcast does not properly handle np.broadcast
#     456     # objects (it treats them as scalars)
#     457     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (2,) and arg 1 with shape (9,).

# %% [markdown]
# ### Standardizing The Module
#
# Q: how do we standardize the x_train, y_train inputs
# Q: what do we do about the output one hot encoding (temp function right now in .get_descent method)
# Q: setting up epochs
#
# Major Question: Do we want things like epoch optimization to all be parts of the network class, or do have other parent classes/functions/etc. that use this simple network. Descent is already part of the class so I think it makes sense to do that.

# %% [markdown]
# ### Pick the Best of 20

# %% [markdown]
# ### Graphing Alpha, Batch Size, etc.
